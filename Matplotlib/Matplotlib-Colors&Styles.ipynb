# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,11,10)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])


ax.plot(x,x,color='green',lw=5,label="X vs X") #hex-color-picker

#possible linestype options '--','-','-.',':','steps'
#lines = ax.plot(x,x+1,color='violet',linestyle='--',label="X vs X+1")
lines[0].set_dashes([5,2,10,2])

lines = ax.plot(x,x,color='violet',linewidth=2,marker='o',ls='--')

lines = ax.plot(x,x+1,color='violet',linewidth=2,marker='+',ls='--',markersize=20,markerfacecolor='red',markeredgewidth=8,markeredgecolor='orange')


ax.legend()

# %%
type(lines)
# Out:
# list
