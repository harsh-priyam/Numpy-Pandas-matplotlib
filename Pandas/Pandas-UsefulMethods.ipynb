# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('F:\\DataScience\\03-Pandas\\tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
str(123456789)[-4:]
# Out:
# '6789'

# %%
def lastFour(num):
    return str(num)[-4:]

# %%
lastFour(93424324324)
# Out:
# '4324'

# %%
df['lastFour'] = df['CC Number'].apply(lastFour)

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df['total_bill'].mean()
# Out:
# 19.785942622950824

# %%
def yelp(price):
    if(price < 10):
        return '$'
    elif(price>=10 and price<30):
        return '$$'
    else:
        return '$$$'

# %%
df['yelp'] = df['total_bill'].apply(yelp)

# %%
df['yelp']
# Out:
# 0      $$
# 1      $$
# 2      $$
# 3      $$
# 4      $$
#        ..
# 239    $$
# 240    $$
# 241    $$
# 242    $$
# 243    $$
# Name: yelp, Length: 244, dtype: object

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID lastFour yelp
# 0    Christy Cunningham  3560325168603410    Sun2959     3410   $$
# 1        Douglas Tucker  4478071379779230    Sun4608     9230   $$
# 2        Travis Walters  6011812112971322    Sun4458     1322   $$
# 3      Nathaniel Harris  4676137647685994    Sun5260     5994   $$
# 4          Tonya Carter  4832732618637221    Sun2251     7221   $$
# ..                  ...               ...        ...      ...  ...
# 239       Michael Avila  5296068606052842    Sat2657     2842   $$
# 240      Monica Sanders  3506806155565404    Sat1766     5404   $$
# 241          Keith Wong  6011891618747196    Sat3880     7196   $$
# 242        Dennis Dixon     4375220550950      Sat17     0950   $$
# 243     Michelle Hardin  3511451626698139    Thur672     8139   $$
#
# [244 rows x 13 columns]

# %%
def square(num):
    return num*num

# %%
square(2)
# Out:
# 4

# %%
lambda num : num*2
# Out:
# <function __main__.<lambda>(num)>

# %%
df['total_bill'].apply(lambda num : num * 2)
# Out:
# 0      33.98
# 1      20.68
# 2      42.02
# 3      47.36
# 4      49.18
#        ...
# 239    58.06
# 240    54.36
# 241    45.34
# 242    35.64
# 243    37.56
# Name: total_bill, Length: 244, dtype: float64

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID lastFour yelp
# 0  Christy Cunningham  3560325168603410    Sun2959     3410   $$
# 1      Douglas Tucker  4478071379779230    Sun4608     9230   $$
# 2      Travis Walters  6011812112971322    Sun4458     1322   $$
# 3    Nathaniel Harris  4676137647685994    Sun5260     5994   $$
# 4        Tonya Carter  4832732618637221    Sun2251     7221   $$

# %%
def quality(total_bill,tip):
    if (tip/total_bill > 0.25):
        return "Generous"
    else:
        return "Ordinary"

# %%
quality(16.99,1.01)
# Out:
# 'Ordinary'

# %%
df['Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'], df['tip']),axis = 1)

# %%
df['Quality'] = np.vectorize(quality)(df['total_bill'],df['tip'])

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID lastFour yelp   Quality
# 0    Christy Cunningham  3560325168603410    Sun2959     3410   $$  Ordinary
# 1        Douglas Tucker  4478071379779230    Sun4608     9230   $$  Ordinary
# 2        Travis Walters  6011812112971322    Sun4458     1322   $$  Ordinary
# 3      Nathaniel Harris  4676137647685994    Sun5260     5994   $$  Ordinary
# 4          Tonya Carter  4832732618637221    Sun2251     7221   $$  Ordinary
# ..                  ...               ...        ...      ...  ...       ...
# 239       Michael Avila  5296068606052842    Sat2657     2842   $$  Ordinary
# 240      Monica Sanders  3506806155565404    Sat1766     5404   $$  Ordinary
# 241          Keith Wong  6011891618747196    Sat3880     7196   $$  Ordinary
# 242        Dennis Dixon     4375220550950      Sat17     0950   $$  Ordinary
# 243     Michelle Hardin  3511451626698139    Thur672     8139   $$  Ordinary
#
# [244 rows x 14 columns]

# %%
import timeit
